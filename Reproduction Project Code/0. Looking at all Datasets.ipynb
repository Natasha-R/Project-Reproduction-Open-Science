# %%
import pandas as pd
import numpy as np

# %%
supp_repeat = pd.read_csv("../Supplementary Study (Repeated Presentation)/supp_study_repeated_data.csv")
supp_work_mem = pd.read_csv("../Supplementary Study (Working Memory)/supp_study_working_data.csv")
main_faces = pd.read_csv("../Main Study (Face)/main_study_face_data.csv")
main_voices = pd.read_csv("../Main Study (Voice)/main_study_voice_data.csv")

# %%
supp_repeat
# Out:
#       Subj  Cond  Block  Trial  Order  Resp   Name  \
# 0        1     1      1      1      1    49      N
# 1        1     1      1      2      2   205  RIGHT
# 2        1     1      1      3      3     9      9
# 3        1     1      1      3      4    57  SPACE
# 4        1     1      1      4     15     9      9
# ...    ...   ...    ...    ...    ...   ...    ...
# 5728    63     1      1    167    147    -1     19
# 5729    63     1      1    168    148     1      1
# 5730    63     1      1    169    149     3      3
# 5731    63     1      1    170    150     2      2
# 5732    63     1      1    178    151    57  SPACE
#
#                                 Stim       RT  Correct
# 0       Please wait for instructions    70648     True
# 1     instructionfollowup\Slide1.bmp    10817     True
# 2     instructionfollowup\Slide2.bmp      796    False
# 3     instructionfollowup\Slide3.bmp     3585     True
# 4                  mfaces\Slide1.bmp     1332    False
# ...

# %%
supp_work_mem = supp_work_mem.dropna(axis=0, how="all")
supp_work_mem["Subj"] = supp_work_mem["Subj"].astype("int")

# %%
supp_work_mem
# Out:
#       Subj  Cond  Block  Trial  Order  Resp  Name         Stim       RT  load  \
# 1        1   1.0    1.0   66.0   41.0   4.0   4.0  Slide32.bmp   1764.0   6.0
# 3        1   1.0    1.0   23.0   38.0   5.0   5.0  Slide22.bmp   3683.0   6.0
# 5        1   1.0    1.0   24.0   37.0   3.0   3.0  Slide23.bmp   3796.0   6.0
# 7        1   1.0    1.0   40.0   25.0   3.0   3.0  Slide32.bmp   1678.0   4.0
# 9        1   1.0    1.0   63.0   22.0   3.0   3.0  Slide29.bmp   8981.0   4.0
# ...    ...   ...    ...    ...    ...   ...   ...          ...      ...   ...
# 3597  1013   1.0    1.0   36.0   22.0   8.0   8.0  Slide24.bmp   3951.0   7.0
# 3599  1013   1.0    1.0   62.0   21.0   8.0   8.0  Slide28.bmp   4214.0   7.0
# 3601  1013   1.0    1.0   14.0    9.0   2.0   2.0  Slide32.bmp   2819.0   2.0
# 3603  1013   1.0    1.0   63.0    6.0   3.0   3.0  Slide29.bmp   8495.0   2.0
# 3605  1013   1.0    1.0   24.0    5.0   4.0   4.0  Slide23.bmp  18322.0   2.0
#
# ...

# %%
main_faces
# Out:
#         id  order  prime  masc               stim  cond
# 0       11      2      0     0  faces\Slide11.bmp     1
# 1       11      3      0     1   faces\Slide9.bmp     1
# 2       11      4      0     0   faces\Slide5.bmp     1
# 3       11      5      0     1   faces\Slide1.bmp     1
# 4       11      6      0     1  faces\Slide18.bmp     1
# ...    ...    ...    ...   ...                ...   ...
# 12659  75b     36      1     1  faces\Slide20.bmp     5
# 12660  75b     37      1     1   faces\Slide2.bmp     5
# 12661  75b     38      1     1  faces\Slide10.bmp     5
# 12662  75b     39      1     0  faces\Slide14.bmp     5
# 12663  75b     40      1     0  faces\Slide11.bmp     5
#
# [12664 rows x 6 columns]

# %%
main_voices
# Out:
#        id  order  masc         stim  cond
# 0      11      1     8  Slide32.bmp     1
# 1      11      2     7  Slide32.bmp     1
# 2      11      3     8  Slide32.bmp     1
# 3      11      4     7  Slide32.bmp     1
# 4      11      5     9  Slide32.bmp     1
# ...   ...    ...   ...          ...   ...
# 1981  75b      2     8  Slide32.bmp     5
# 1982  75b      3     5  Slide32.bmp     5
# 1983  75b      4     6  Slide32.bmp     5
# 1984  75b      5     5  Slide32.bmp     5
# 1985  75b      6     5  Slide32.bmp     5
#
# [1986 rows x 5 columns]
